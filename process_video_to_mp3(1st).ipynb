# %%
#converts mp4 to mp3

import os
import subprocess
files = os.listdir("Videos")
for file in files:
    tutorial_number=file.split(".")[0]
    tutorial_name=file.split(".")[1]
    print(f"Converting {tutorial_number}-{tutorial_name} to mp3")
    subprocess.run(["ffmpeg", "-i",f"Videos/{file}", f"Audios/{tutorial_number}-{tutorial_name}.mp3"])
print("✅ All videos converted from MP4 to MP3")
# Out:
# Converting 3 - THE HUNGRY FOX STUCK IN THE TREE HOLE to mp3
# Converting 5 - THE-DOVE-and-THE-ANT-Story-Kids-Short-Story to mp3
# Converting 1 - The Bundle Of Sticks Story  Stories for Kids to mp3
# Converting 2 - The Goose Girl Story  Stories for Kids to mp3
# Converting 4 - THE MAGIC POT STORY  STORIES FOR KIDS  TRADITIONAL STORY  to mp3
# ✅ All videos converted from MP4 to MP3
